# %% [markdown]
# Задание 1.
#
# Вычислить вектор градиента и матрицу Гессе для функции:
#
# f(x) = 2*x1**3 - 3*x1*x2 + 2*x2*x3**2 - x2**3
#
# В точке M=(2,1,1).

# %%
import sympy as sym

# %%
x1 = sym.Symbol('x1')
x2 = sym.Symbol('x2')
x3 = sym.Symbol('x3')

# %%
sym.diff(2*x1**3 - 3*x1*x2 + 2*x2*x3**2 - x2**3, x1)
# Out:
# 6*x1**2 - 3*x2

# %%
sym.diff(2*x1**3 - 3*x1*x2 + 2*x2*x3**2 - x2**3, x2)
# Out:
# -3*x1 - 3*x2**2 + 2*x3**2

# %%
sym.diff(2*x1**3 - 3*x1*x2 + 2*x2*x3**2 - x2**3, x3)
# Out:
# 4*x2*x3

# %% [markdown]
# Вектор градиента в точке М (21, -7, 4)

# %% [markdown]
# Матрица Гессе:
#
#      12x1; -3; 0
#
# H(f) = -3;  -6x2; 4x3
#
#       0, 4x3; 4x2
#
# В точке М
#
# 24  -3  0
#
# -3  -6  4
#
# 0    4  4

# %% [markdown]
# Задание 2
#
# Постройте график трехмерный функции:
#
# f(x) = x2**2 - x1**2*x2 + 2*x1*x2

# %%
#from mpl_toolkits.mplot3d import Axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
fig = plt.figure()
ax = fig.gca(projection= '3d')

X = np.arange(-5, 5, 0.25) 
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X , Y)
R = np.sqrt(X**2 + Y**2)
Z = func02(X, Y)

surf = ax.plot_surface(X, Y, Z, cmap = cm.coolwarm,
                      linewidth = 0, antialiased = False)

ax.set_zlim(-1, 200.0)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink = 0.5, aspect = 20)

plt.show()

# %%
def func02(x1, x2):
    return x2**2 - x1**2*x2 + 2*x1*x2

# %% [markdown]
# Задание 3
#
# Построить график линий уровня с уровнями {1,5,10}

# %%
x = np.arange(-3.0, 3.0, 0.025)
y = np.arange(-3.0, 3.0, 0.025)
X, Y = np.meshgrid(x , y)
Z1 = np.exp(X**2 + Y**2)
Z2 = np.exp((X + 1)**2 + (Y + 1)**2)
Z = (Z1 - Z2) * 2

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, [ 1, 5, 10])
ax.clabel(CS, inline = True, fontsize = 7)
# Out:
# <a list of 3 text.Text objects>
