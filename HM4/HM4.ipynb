# %% [markdown]
# Задание 1.
#
# Вычислить значения первой и второй производной функции:
#
# f(x) = x^5 + 4*sin*(2*x) + cos*(3x+3)
#
# Первая производная:
#
# 5x^4 + 8cos(2x) - 3sin(3x+3)
#
# В точке х =1
#
# 5 + 8cos(2) - 3sin(6)
#
# Вторая производная
#
# 20x**3 - 16*sin(2x) - 9*cos*(3x+3)
#
# В точке x = 1
#
# 20 - 16sin(2) - 9cos(6)

# %% [markdown]
# Задание 2.
#
# Постройте график функции, первой и второй производной:
#
# f(x) = sin**5(2x+1)
#
# На отрезке [-5; 5].

# %%
import sympy as sym

# %%
x = sym.Symbol('x')

# %%
res = sym.diff((sym.sin(2*x+1))**5)
res
# Out:
# 10*sin(2*x + 1)**4*cos(2*x + 1)

# %%
res2 = sym.diff((sym.sin(2*x+1))**5, x, 2)
res2
# Out:
# 20*(-sin(2*x + 1)**2 + 4*cos(2*x + 1)**2)*sin(2*x + 1)**3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5, 0.1)

# %%
y = (np.sin(2*x+1)**5)

# %%
plt.plot(x, y)
plt.title('Функция')
plt.show()

# %%
z = 10*((np.sin(2*x-1))**4)*np.cos(2*x+1)

# %%
plt.plot(x, z)
plt.title('Первая производная')
plt.show()

# %%
w = 20*((-(np.sin(2*x+1)**2)) + 4*(np.cos(2*x+1)**2))*(np.sin(2*x+1)**3)

# %%
plt.plot(x, w)
plt.title('Вторая производная')
plt.show()
