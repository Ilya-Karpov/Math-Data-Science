# %% [markdown]
# Задание 1
#
# Монетку подбрасывают 15 раз, найдите вероятность выпадения простого числа орлов.

# %% [markdown]
# По результатам вычислений, используя формулу Бернулли, сумма вероятностей выпадения простого числа (2, 3, 5, 7, 11, 13) орлов составила ≈ 35%
#
# Вычитаем по очереди вероятность выпадения того или иного простого числа орлов, по нижеприведенной формуле:

# %% [markdown]
# P = Cn**k * 0.5**n

# %% [markdown]
# где n - количество бросков, а k - необходимое количество выпадений орла.
#
# Сn**k = n! / k! * (n - k)!
#
# 0.5 - вероятность выпадения орла в каждом броске одинакова

# %% [markdown]
# Задание 2
#
# Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
fig, ax = plt.subplots()

x = np.linspace(-10, 10, 100)

norm1 = stats.norm(loc = 1.0, scale = 1.0)
ax.plot(x, norm1.pdf(x))
norm2 = stats.norm(loc = 6.0, scale = 1.0)
ax.plot(x, norm2.pdf(x))
norm3 = stats.norm(loc = 3.5, scale = 0.5)
ax.plot(x, norm3.pdf(x))
norm4 = stats.norm(loc = -2.0, scale = 0.3)
ax.plot(x, norm4.pdf(x))
norm5 = stats.norm(loc = 0, scale = 3.0)
ax.plot(x, norm5.pdf(x))

plt.show()

# %%
fig, ax = plt.subplots()

x = np.linspace(-2, 10, 100)

expon1 = stats.expon(0)
ax.plot(x, expon1.pdf(x))
expon2 = stats.expon(1)
ax.plot(x, expon2.pdf(x))
expon3 = stats.expon(4)
ax.plot(x, expon3.pdf(x))
expon4 = stats.expon(3)
ax.plot(x, expon4.pdf(x))
expon5 = stats.expon(7)
ax.plot(x, expon5.pdf(x))

plt.show()

# %%
fig, ax = plt.subplots()

x = np.linspace(-10, 10, 100)

t1 = stats.t(100)
ax.plot(x, t1.pdf(x))
t2 = stats.t(0.005)
ax.plot(x, t2.pdf(x))
t3 = stats.t(0.1)
ax.plot(x, t3.pdf(x))
t4 = stats.t(0.03)
ax.plot(x, t4.pdf(x))
t5 = stats.t(1)
ax.plot(x, t5.pdf(x))

plt.show()
